# %%
from tsts.tools import Forecaster


forecaster = Forecaster(batch_size=2)

# %%
forecaster

# %%
import torch


X = torch.randn(256, 4)
forecaster.fit(X)
# Out:
# [tensor([[[-3.0336e-01,  2.2459e+00,  2.2561e+00, -6.6783e-01],
#          [-1.8812e-01,  8.3854e-01,  5.3015e-01,  6.3114e-01],
#          [-1.9504e+00, -3.1808e-01,  2.7391e-02,  7.0077e-01],
#          [ 4.5629e-01, -2.5742e-01, -2.0016e+00,  1.9391e-01],
#          [-9.7653e-03,  1.2825e-01, -2.2045e-01,  1.1415e+00],
#          [-4.3091e-01, -6.2898e-01, -2.0015e-01,  1.3387e+00],
#          [-3.6728e-01, -1.8414e+00, -1.0788e+00, -1.4499e+00],
#          [-1.2979e-01, -3.1863e-01,  3.1926e-02, -1.3115e+00],
#          [ 6.8224e-01, -4.9935e-01, -3.6311e-01, -4.8576e-01],
#          [-2.8835e-01, -6.3577e-01,  5.2096e-01, -8.8321e-01],
#          [-8.3618e-01,  3.7337e-01,  8.4373e-01,  9.7955e-03],
#          [ 4.6052e-01, -5.0981e-01, -7.6108e-01, -8.2563e-01],
#          [ 1.1913e+00,  3.7323e-01,  1.0795e+00,  7.2886e-01],
#          [ 1.5036e+00,  6.5741e-01,  8.4517e-01, -7.4222e-01],
#          [-7.5080e-01,  7.3776e-01,  3.9833e-01, -4.9641e-01],
# ...
